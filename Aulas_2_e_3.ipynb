# %% [markdown]
# Aula 2 - Importação

# %%
import pandas as pd
import plotly.express as px

# %%
df_principal = pd.read_excel("Imersão Python - Tabela de ações.xlsx", sheet_name="Principal")
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1   CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2   PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3   SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4   CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# ..    ...        ...          ...           ...            ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45          -9.47        -13.98
# 77  BHIA3 2024-01-26         8.70         -2.46          -6.95        -23.55
# 78  RENT3 2024-01-26        56.24         -3.63          -6.41        -11.57
# 79  CVCB3 2024-01-26         3.07         -4.36          -5.54        -12.29
# 80  GOLL4 2024-01-26         5.92         -8.07         -15.91        -34.00
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume  Variação %  \
# 0           2.26         15.97      9.18      9.56  319,16 M        0.05
# 1         -12.11         50.56      6.66      6.86   32,65 M        0.02
# 2           7.64         77.55     40.81     42.34  436,69 M        0.02
# 3          -4.89         18.85     51.89     53.17  162,55 M        0.02
# 4          -3.66         20.70     36.37     37.32   73,42 M        0.02
# ..           ...           ...       ...       ...       ...         ...
# 76        -13.98        -32.72     10.70     11.08   38,19 M       -0.02
# 77        -23.55        -85.74      8.67      8.95   27,54 M       -0.02
# 78        -11.57         -2.77     56.04     58.90  624,74 M       -0.04
# 79        -12.29        -36.83      3.05      3.23  101,46 M       -0.04
# 80        -34.00        -25.44      5.51      6.02  154,36 M       -0.08
#
#     Valor Inicial (R$)  Quantidade de Ações       Variação Resultado  \
# 0                 9.03            515117391   241889725.40     Subiu
# 1                 6.66           1110559345   177515970.30     Subiu
# 2                41.06           2379877655  2140059394.00     Subiu
# 3                51.85            683452836   722946282.70     Subiu
# 4                36.36            187732538   138573955.10     Subiu
# ..                 ...                  ...            ...       ...
# 76               10.98            533990587  -143635530.60    Desceu
# 77                8.92             94843047   -20810240.84    Desceu
# 78               58.36            853202347 -1807432634.00    Desceu
# 79                3.21            525582771   -73557408.06    Desceu
# 80                6.44            198184909  -102993202.60    Desceu
#
#      Nome da Empresa           Segmento  Idade   Categoria de Idade
# 0           Usiminas         Siderurgia     64  Entre 50 e 100 anos
# 1      CSN Mineração          Mineração      8     Menos de 50 anos
# 2          Petrobras     Petróleo e Gás     68  Entre 50 e 100 anos
# 3             Suzano   Papel e Celulose     97  Entre 50 e 100 anos
# 4       CPFL Energia   Energia Elétrica    109     Mais de 100 anos
# ..               ...                ...    ...                  ...
# 76  Carrefour Brasil             Varejo     45     Menos de 50 anos
# 77       Casas Bahia             Varejo     70  Entre 50 e 100 anos
# 78          Localiza  Aluguel de Carros     48     Menos de 50 anos
# 79               CVC            Turismo     49     Menos de 50 anos
# 80               GOL   Transporte Aéreo     21     Menos de 50 anos
#
# [81 rows x 20 columns]

# %%
df_total_de_acoes = pd.read_excel("Imersão Python - Tabela de ações.xlsx", sheet_name="Total_de_acoes")
df_total_de_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   235665566.00
# 1                      ALOS3   532616595.00
# 2                      ALPA4   176733968.00
# 3                      ABEV3  4394245879.00
# 4                      ARZZ3    62305891.00
# ..                       ...            ...
# 84                     VBBR3  1114412532.00
# 85                     WEGE3  1481593024.00
# 86                     YDUQ3   289347914.00
# 87  Quantidade Teórica Total 96372098181.00
# 88                   Redutor    17047850.79
#
# [89 rows x 2 columns]

# %%
df_ticker = pd.read_excel("Imersão Python - Tabela de ações.xlsx", sheet_name="Ticker")
df_ticker
# Out:
#     Ticker            Nome
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_chatgpt = pd.read_excel("Imersão Python - Tabela de ações.xlsx", sheet_name="Chat GPT")
df_chatgpt
# Out:
#      Nome da Empresa           Segmento  Idade em anos
# 0           Usiminas         Siderurgia             64
# 1      CSN Mineração          Mineração              8
# 2          Petrobras     Petróleo e Gás             68
# 3             Suzano   Papel e Celulose             97
# 4       CPFL Energia   Energia Elétrica            109
# ..               ...                ...            ...
# 73  Carrefour Brasil             Varejo             45
# 74       Casas Bahia             Varejo             70
# 75          Localiza  Aluguel de Carros             48
# 76               CVC            Turismo             49
# 77               GOL   Transporte Aéreo             21
#
# [78 rows x 3 columns]

# %%
df_principal = df_principal[['Ativo', 'Data', 'Último (R$)', 'Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_principal = df_principal.rename(columns={'Último (R$)' : 'valor_final', 'Var. Dia (%)' : 'var_dia_pct'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3 2024-01-26        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
df_principal['Var_pct'] = df_principal['var_dia_pct']/100
df_principal['valor_inicial'] = df_principal['valor_final']/(df_principal['Var_pct']+1)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
# [81 rows x 6 columns]

# %%
df_principal = df_principal.merge(df_total_de_acoes, left_on='Ativo', right_on='Código', how='left')
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44  GOLL4
#
#     Qtde. Teórica
# 0    515117391.00
# 1   1110559345.00
# 2   2379877655.00
# 3    683452836.00
# 4    187732538.00
# ..            ...
# 76   533990587.00
# 77    94843047.00
# 78   853202347.00
# 79   525582771.00
# 80   198184909.00
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.drop(columns=['Código'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica
# 0    515117391.00
# 1   1110559345.00
# 2   2379877655.00
# 3    683452836.00
# 4    187732538.00
# ..            ...
# 76   533990587.00
# 77    94843047.00
# 78   853202347.00
# 79   525582771.00
# 80   198184909.00
#
# [81 rows x 7 columns]

# %%
df_principal['Variacao_rs'] = (df_principal['valor_final'] - df_principal['valor_inicial'])*df_principal['Qtde. Teórica']
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_rs
# 0    515117391.00   241889725.43
# 1   1110559345.00   177515970.30
# 2   2379877655.00  2140059393.53
# 3    683452836.00   722946282.71
# 4    187732538.00   138573955.06
# ..            ...            ...
# 76   533990587.00  -143635530.57
# 77    94843047.00   -20810240.84
# 78   853202347.00 -1807432634.46
# 79   525582771.00   -73557408.06
# 80   198184909.00  -102993202.62
#
# [81 rows x 8 columns]

# %%
pd.options.display.float_format = '{:.2f}'.format
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_rs
# 0    515117391.00   241889725.43
# 1   1110559345.00   177515970.30
# 2   2379877655.00  2140059393.53
# 3    683452836.00   722946282.71
# 4    187732538.00   138573955.06
# ..            ...            ...
# 76   533990587.00  -143635530.57
# 77    94843047.00   -20810240.84
# 78   853202347.00 -1807432634.46
# 79   525582771.00   -73557408.06
# 80   198184909.00  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Qtde. Teórica'] = df_principal['Qtde. Teórica'].astype(int)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_rs
# 0       515117391   241889725.43
# 1      1110559345   177515970.30
# 2      2379877655  2140059393.53
# 3       683452836   722946282.71
# 4       187732538   138573955.06
# ..            ...            ...
# 76      533990587  -143635530.57
# 77       94843047   -20810240.84
# 78      853202347 -1807432634.46
# 79      525582771   -73557408.06
# 80      198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica' : 'qtd_teorica'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    Variacao_rs
# 0     515117391   241889725.43
# 1    1110559345   177515970.30
# 2    2379877655  2140059393.53
# 3     683452836   722946282.71
# 4     187732538   138573955.06
# ..          ...            ...
# 76    533990587  -143635530.57
# 77     94843047   -20810240.84
# 78    853202347 -1807432634.46
# 79    525582771   -73557408.06
# 80    198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Resultado'] = df_principal['Variacao_rs'].apply(lambda x: 'Subiu' if x > 0 else ('Desceu' if x < 0 else 'Estável'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    Variacao_rs Resultado
# 0     515117391   241889725.43     Subiu
# 1    1110559345   177515970.30     Subiu
# 2    2379877655  2140059393.53     Subiu
# 3     683452836   722946282.71     Subiu
# 4     187732538   138573955.06     Subiu
# ..          ...            ...       ...
# 76    533990587  -143635530.57    Desceu
# 77     94843047   -20810240.84    Desceu
# 78    853202347 -1807432634.46    Desceu
# 79    525582771   -73557408.06    Desceu
# 80    198184909  -102993202.62    Desceu
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.merge(df_ticker, left_on='Ativo', right_on='Ticker', how='left')
df_principal = df_principal.drop(columns=['Ticker'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    Variacao_rs Resultado              Nome
# 0     515117391   241889725.43     Subiu          Usiminas
# 1    1110559345   177515970.30     Subiu     CSN Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras
# 3     683452836   722946282.71     Subiu            Suzano
# 4     187732538   138573955.06     Subiu      CPFL Energia
# ..          ...            ...       ...               ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil
# 77     94843047   -20810240.84    Desceu       Casas Bahia
# 78    853202347 -1807432634.46    Desceu          Localiza
# 79    525582771   -73557408.06    Desceu               CVC
# 80    198184909  -102993202.62    Desceu               GOL
#
# [81 rows x 10 columns]

# %%
df_principal = df_principal.merge(df_chatgpt, left_on='Nome', right_on='Nome da Empresa', how='left')
df_principal = df_principal.drop(columns=['Nome'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    Variacao_rs Resultado   Nome da Empresa           Segmento  \
# 0     515117391   241889725.43     Subiu          Usiminas         Siderurgia
# 1    1110559345   177515970.30     Subiu     CSN Mineração          Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras     Petróleo e Gás
# 3     683452836   722946282.71     Subiu            Suzano   Papel e Celulose
# 4     187732538   138573955.06     Subiu      CPFL Energia   Energia Elétrica
# ..          ...            ...       ...               ...                ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil             Varejo
# 77     94843047   -20810240.84    Desceu       Casas Bahia             Varejo
# 78    853202347 -1807432634.46    Desceu          Localiza  Aluguel de Carros
# 79    525582771   -73557408.06    Desceu               CVC            Turismo
# 80    198184909  -102993202.62    Desceu               GOL   Transporte Aéreo
#
#     Idade em anos
# 0              64
# 1               8
# 2              68
# 3              97
# 4             109
# ..            ...
# 76             45
# 77             70
# 78             48
# 79             49
# 80             21
#
# [81 rows x 12 columns]

# %%
df_principal = df_principal.rename(columns={'Idade (fundação ou início de operações)':'Idade'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    Variacao_rs Resultado   Nome da Empresa           Segmento  \
# 0     515117391   241889725.43     Subiu          Usiminas         Siderurgia
# 1    1110559345   177515970.30     Subiu     CSN Mineração          Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras     Petróleo e Gás
# 3     683452836   722946282.71     Subiu            Suzano   Papel e Celulose
# 4     187732538   138573955.06     Subiu      CPFL Energia   Energia Elétrica
# ..          ...            ...       ...               ...                ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil             Varejo
# 77     94843047   -20810240.84    Desceu       Casas Bahia             Varejo
# 78    853202347 -1807432634.46    Desceu          Localiza  Aluguel de Carros
# 79    525582771   -73557408.06    Desceu               CVC            Turismo
# 80    198184909  -102993202.62    Desceu               GOL   Transporte Aéreo
#
#     Idade em anos
# 0              64
# 1               8
# 2              68
# 3              97
# 4             109
# ..            ...
# 76             45
# 77             70
# 78             48
# 79             49
# 80             21
#
# [81 rows x 12 columns]

# %%
df_principal = df_principal.rename(columns={'Idade em anos':'Ano_de_fundacao'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    Variacao_rs Resultado   Nome da Empresa           Segmento  \
# 0     515117391   241889725.43     Subiu          Usiminas         Siderurgia
# 1    1110559345   177515970.30     Subiu     CSN Mineração          Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras     Petróleo e Gás
# 3     683452836   722946282.71     Subiu            Suzano   Papel e Celulose
# 4     187732538   138573955.06     Subiu      CPFL Energia   Energia Elétrica
# ..          ...            ...       ...               ...                ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil             Varejo
# 77     94843047   -20810240.84    Desceu       Casas Bahia             Varejo
# 78    853202347 -1807432634.46    Desceu          Localiza  Aluguel de Carros
# 79    525582771   -73557408.06    Desceu               CVC            Turismo
# 80    198184909  -102993202.62    Desceu               GOL   Transporte Aéreo
#
#     Ano_de_fundacao
# 0                64
# 1                 8
# 2                68
# 3                97
# 4               109
# ..              ...
# 76               45
# 77               70
# 78               48
# 79               49
# 80               21
#
# [81 rows x 12 columns]

# %%
df_principal['Cat_idade'] = df_principal['Ano_de_fundacao'].apply(lambda x: 'Mais de 100' if x > 100 else ('Menos de 50' if x < 50 else 'Entre 50 e 100'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    Variacao_rs Resultado   Nome da Empresa           Segmento  \
# 0     515117391   241889725.43     Subiu          Usiminas         Siderurgia
# 1    1110559345   177515970.30     Subiu     CSN Mineração          Mineração
# 2    2379877655  2140059393.53     Subiu         Petrobras     Petróleo e Gás
# 3     683452836   722946282.71     Subiu            Suzano   Papel e Celulose
# 4     187732538   138573955.06     Subiu      CPFL Energia   Energia Elétrica
# ..          ...            ...       ...               ...                ...
# 76    533990587  -143635530.57    Desceu  Carrefour Brasil             Varejo
# 77     94843047   -20810240.84    Desceu       Casas Bahia             Varejo
# 78    853202347 -1807432634.46    Desceu          Localiza  Aluguel de Carros
# 79    525582771   -73557408.06    Desceu               CVC            Turismo
# 80    198184909  -102993202.62    Desceu               GOL   Transporte Aéreo
#
#     Ano_de_fundacao       Cat_idade
# 0                64  Entre 50 e 100
# 1                 8     Menos de 50
# 2                68  Entre 50 e 100
# 3                97  Entre 50 e 100
# 4               109     Mais de 100
# ..              ...             ...
# 76               45     Menos de 50
# 77               70  Entre 50 e 100
# 78               48     Menos de 50
# 79               49     Menos de 50
# 80               21     Menos de 50
#
# [81 rows x 13 columns]

# %%
# Calculando o maior valor
maior = df_principal['Variacao_rs'].max()

# Calculando o menor valor
menor = df_principal['Variacao_rs'].min()

# Calculando a média
media = df_principal['Variacao_rs'].mean()

# Calculando a média de quem subiu
media_subiu = df_principal[df_principal['Resultado'] == 'Subiu']['Variacao_rs'].mean()

# Calculando a média de quem desceu
media_desceu = df_principal[df_principal['Resultado'] == 'Desceu']['Variacao_rs'].mean()

# Imprimindo os resultados
print(f"Maior\tR$ {maior:,.2f}")
print(f"Menor\tR$ {menor:,.2f}")
print(f"Média\tR$ {media:,.2f}")
print(f"Média de quem subiu\tR$ {media_subiu:,.2f}")
print(f"Média de quem desceu\tR$ {media_desceu:,.2f}")
# Out:
# Maior	R$ 4,762,926,995.25
# Menor	R$ -1,807,432,634.46
# Média	R$ 165,190,210.48
# Média de quem subiu	R$ 448,164,250.23
# Média de quem desceu	R$ -181,109,141.75

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
df_principal_subiu
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# 5   PRIO3 2024-01-26        45.69         1.98     0.02          44.80
# 6   PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 7   VALE3 2024-01-26        69.50         1.66     0.02          68.37
# 8   MULT3 2024-01-26        28.19         1.58     0.02          27.75
# 9   ITUB4 2024-01-26        32.81         1.48     0.01          32.33
# 10  RDOR3 2024-01-26        27.56         1.43     0.01          27.17
# 11  BRKM5 2024-01-26        18.55         1.42     0.01          18.29
# 12  AZUL4 2024-01-26        14.27         1.42     0.01          14.07
# 13  RRRP3 2024-01-26        28.75         1.41     0.01          28.35
# 14  EQTL3 2024-01-26        35.32         1.34     0.01          34.85
# 15  CSNA3 2024-01-26        18.16         1.33     0.01          17.92
# 16  YDUQ3 2024-01-26        19.77         1.28     0.01          19.52
# 17  UGPA3 2024-01-26        28.31         1.28     0.01          27.95
# 18  MRVE3 2024-01-26         8.08         1.25     0.01           7.98
# 19  ARZZ3 2024-01-26        57.91         1.15     0.01          57.25
# 20  BBDC4 2024-01-26        15.52         1.04     0.01          15.36
# 21  BEEF3 2024-01-26         7.19         0.98     0.01           7.12
# 22  PCAR3 2024-01-26         4.14         0.97     0.01           4.10
# 23  BRFS3 2024-01-26        14.61         0.96     0.01          14.47
# 24  VIVT3 2024-01-26        51.20         0.88     0.01          50.75
# 25  RAIL3 2024-01-26        22.64         0.84     0.01          22.45
# 26  CIEL3 2024-01-26         4.90         0.82     0.01           4.86
# 27  DXCO3 2024-01-26         7.81         0.77     0.01           7.75
# 28  TIMS3 2024-01-26        17.52         0.74     0.01          17.39
# 29  BRAP4 2024-01-26        23.22         0.73     0.01          23.05
# 30  LWSA3 2024-01-26         5.55         0.72     0.01           5.51
# 31  RECV3 2024-01-26        23.83         0.71     0.01          23.66
# 32  ITSA4 2024-01-26        10.01         0.70     0.01           9.94
# 33  BBAS3 2024-01-26        56.97         0.68     0.01          56.59
# 34  RADL3 2024-01-26        26.16         0.61     0.01          26.00
# 35  GOAU4 2024-01-26        10.08         0.59     0.01          10.02
# 36  CSAN3 2024-01-26        18.57         0.59     0.01          18.46
# 37  JBSS3 2024-01-26        24.34         0.57     0.01          24.20
# 38  MGLU3 2024-01-26         2.08         0.48     0.00           2.07
# 39  BBDC3 2024-01-26        13.75         0.36     0.00          13.70
# 40  GGBR4 2024-01-26        21.84         0.27     0.00          21.78
# 41  RAIZ4 2024-01-26         3.74         0.26     0.00           3.73
# 42  CPLE6 2024-01-26        10.07         0.19     0.00          10.05
# 43  VAMO3 2024-01-26         8.18         0.12     0.00           8.17
#
#     qtd_teorica   Variacao_rs Resultado       Nome da Empresa  \
# 0     515117391  241889725.43     Subiu              Usiminas
# 1    1110559345  177515970.30     Subiu         CSN Mineração
# 2    2379877655 2140059393.53     Subiu             Petrobras
# 3     683452836  722946282.71     Subiu                Suzano
# 4     187732538  138573955.06     Subiu          CPFL Energia
# 5     800010734  709687498.18     Subiu              PetroRio
# 6    4566445852 3103136291.22     Subiu             Petrobras
# 7    4196924316 4762926995.25     Subiu                  Vale
# 8     268505432  117732680.08     Subiu             Multiplan
# 9    4801593832 2297591984.33     Subiu         Itaú Unibanco
# 10   1168230366  453917907.01     Subiu             Rede D'Or
# 11    265877867   69054317.64     Subiu               Braskem
# 12    327593725   65452205.55     Subiu                  Azul
# 13    235665566   94204643.35     Subiu          3R Petroleum
# 14   1095587251  511671895.45     Subiu    Equatorial Energia
# 15    600865451  143220991.46     Subiu  Siderúrgica Nacional
# 16    289347914   72295838.99     Subiu                 YDUQS
# 17   1086411192  388705223.96     Subiu              Ultrapar
# 18    376187582   37525872.38     Subiu                   MRV
# 19     62305891   41021792.09     Subiu                Arezzo
# 20   5146576868  822148336.41     Subiu        Banco Bradesco
# 21    261036182   18214628.10     Subiu               Minerva
# 22    159430826    6340916.22     Subiu   Grupo Pão de Açúcar
# 23   1677525446  233045769.57     Subiu                   BRF
# 24    423091712  188965307.06     Subiu                  Vivo
# 25   1218352541  229771333.63     Subiu                  Rumo
# 26   1095462329   43657683.38     Subiu                 Cielo
# 27    302768240   18068446.61     Subiu                 Dexco
# 28    807896814  103972807.37     Subiu                   TIM
# 29    251003438   42238249.54     Subiu             Bradespar
# 30    393173139   15598886.65     Subiu               Locaweb
# 31    275005663   46201006.00     Subiu        PetroRecôncavo
# 32   5372783971  373853994.88     Subiu                Itaúsa
# 33   1420949112  546752087.99     Subiu       Banco do Brasil
# 34   1275798515  202352473.74     Subiu          RaiaDrogasil
# 35    660411219   39045606.94     Subiu    Metalúrgica Gerdau
# 36   1168097881  127229653.18     Subiu                 Cosan
# 37   1134986472  156573285.43     Subiu                   JBS
# 38   2867627068   28493619.27     Subiu        Magazine Luiza
# 39   1500728902   74019610.05     Subiu        Banco Bradesco
# 40   1118525506   65779607.10     Subiu                Gerdau
# 41   1193047233   11571106.42     Subiu                Raízen
# 42   1679335290   32069789.50     Subiu                 Copel
# 43    421383330    4131341.16     Subiu           Grupo Vamos
#
#                         Segmento  Ano_de_fundacao       Cat_idade
# 0                     Siderurgia               64  Entre 50 e 100
# 1                      Mineração                8     Menos de 50
# 2                 Petróleo e Gás               68  Entre 50 e 100
# 3               Papel e Celulose               97  Entre 50 e 100
# 4               Energia Elétrica              109     Mais de 100
# 5                 Petróleo e Gás                8     Menos de 50
# 6                 Petróleo e Gás               68  Entre 50 e 100
# 7                      Mineração               80  Entre 50 e 100
# 8               Shopping Centers               48     Menos de 50
# 9         Instituição Financeira               13     Menos de 50
# 10                         Saúde               47     Menos de 50
# 11                  Petroquímica               20     Menos de 50
# 12              Transporte Aéreo               14     Menos de 50
# 13                Petróleo e Gás                6     Menos de 50
# 14              Energia Elétrica               24     Menos de 50
# 15                    Siderurgia               82  Entre 50 e 100
# 16                      Educação               58  Entre 50 e 100
# 17  Distribuição de Combustíveis               84  Entre 50 e 100
# 18              Construção Civil               42     Menos de 50
# 19                      Calçados               50  Entre 50 e 100
# 20        Instituição Financeira               79  Entre 50 e 100
# 21                     Alimentos               29     Menos de 50
# 22                        Varejo               62  Entre 50 e 100
# 23                     Alimentos               88  Entre 50 e 100
# 24              Telecomunicações               13     Menos de 50
# 25                     Logística               10     Menos de 50
# 26          Serviços Financeiros               12     Menos de 50
# 27                       Energia               73  Entre 50 e 100
# 28              Telecomunicações               25     Menos de 50
# 29                      Holdings               23     Menos de 50
# 30      Tecnologia da Informação               24     Menos de 50
# 31                Petróleo e Gás                9     Menos de 50
# 32                      Holdings               54  Entre 50 e 100
# 33        Instituição Financeira              213     Mais de 100
# 34                     Farmácias              115     Mais de 100
# 35                    Siderurgia              120     Mais de 100
# 36                       Energia               84  Entre 50 e 100
# 37                     Alimentos               68  Entre 50 e 100
# 38                        Varejo               64  Entre 50 e 100
# 39        Instituição Financeira               79  Entre 50 e 100
# 40                    Siderurgia              120     Mais de 100
# 41                       Energia                9     Menos de 50
# 42                       Energia               67  Entre 50 e 100
# 43                     Logística               20     Menos de 50

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['Variacao_rs'].sum().reset_index()
df_analise_segmento
# Out:
#                         Segmento   Variacao_rs
# 0                      Alimentos  407833683.09
# 1                       Calçados   41021792.09
# 2               Construção Civil   37525872.38
# 3   Distribuição de Combustíveis  388705223.96
# 4                       Educação   72295838.99
# 5                        Energia  188938995.71
# 6               Energia Elétrica  650245850.51
# 7                      Farmácias  202352473.74
# 8                       Holdings  416092244.42
# 9         Instituição Financeira 3740512018.78
# 10                     Logística  233902674.79
# 11                     Mineração 4940442965.55
# 12              Papel e Celulose  722946282.71
# 13                  Petroquímica   69054317.64
# 14                Petróleo e Gás 6093288832.26
# 15                         Saúde  453917907.01
# 16          Serviços Financeiros   43657683.38
# 17              Shopping Centers  117732680.08
# 18                    Siderurgia  489935930.93
# 19      Tecnologia da Informação   15598886.65
# 20              Telecomunicações  292938114.42
# 21              Transporte Aéreo   65452205.55
# 22                        Varejo   34834535.50

# %%
df_analise_saldo = df_principal.groupby('Resultado')['Variacao_rs'].sum().reset_index()
df_analise_saldo['Variacao_rs'] = (df_analise_saldo['Variacao_rs'] / 1e9)
df_analise_saldo
# Out:
#   Resultado  Variacao_rs
# 0    Desceu        -6.34
# 1   Estável         0.00
# 2     Subiu        19.72

# %%
fig = px.bar(df_analise_saldo, x='Resultado', y='Variacao_rs', text='Variacao_rs', title='Variação em Bilhões de Reais por Resultado', color='Resultado')
fig.update_traces(texttemplate='%{text:.1f}B', textposition='outside')
fig.update_layout(template='plotly_dark')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="10d145ee-73b8-4074-b872-326b83d7d028" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10d145ee-73b8-4074-b872-326b83d7d028")) {                    Plotly.newPlot(                        "10d145ee-73b8-4074-b872-326b83d7d028",                        [{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Desceu","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Desceu","offsetgroup":"Desceu","orientation":"v","showlegend":true,"text":[-6.33881996131535],"textposition":"outside","x":["Desceu"],"xaxis":"x","y":[-6.33881996131535],"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}B"},{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Est\u00e1vel","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Est\u00e1vel","offsetgroup":"Est\u00e1vel","orientation":"v","showlegend":true,"text":[0.0],"textposition":"outside","x":["Est\u00e1vel"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}B"},{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Subiu","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Subiu","offsetgroup":"Subiu","orientation":"v","showlegend":true,"text":[19.71922701014191],"textposition":"outside","x":["Subiu"],"xaxis":"x","y":[19.71922701014191],"yaxis":"y","type":"bar","texttemplate":"%{text:.1f}B"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333 ...

# %%
df_analise_cat_idade = df_principal.groupby('Cat_idade')['Variacao_rs'].sum().reset_index()
df_analise_cat_idade
# Out:
#         Cat_idade    Variacao_rs
# 0  Entre 50 e 100 11464272300.66
# 1     Mais de 100  -250815638.02
# 2     Menos de 50  2166950386.18

# %%
fig = px.bar(df_analise_cat_idade, x='Cat_idade', y='Variacao_rs', text='Variacao_rs', title='Variação Reais por Categoria de Idade')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b7a7856d-d05c-4db6-83c4-1335d7a4a414" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7a7856d-d05c-4db6-83c4-1335d7a4a414")) {                    Plotly.newPlot(                        "b7a7856d-d05c-4db6-83c4-1335d7a4a414",                        [{"alignmentgroup":"True","hovertemplate":"Cat_idade=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[11464272300.660904,-250815638.01712644,2166950386.1827836],"textposition":"auto","x":["Entre 50 e 100","Mais de 100","Menos de 50"],"xaxis":"x","y":[11464272300.660904,-250815638.01712644,2166950386.1827836],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"o ...
